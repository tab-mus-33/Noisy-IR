# %%
# The script helps you generate trecxml files for the project 


from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Use to make a directory if you require to store the files 
# !mkdir "/content/drive/MyDrive/IRDM/xml_dir/stemmer"

# %%
# !python '/content/drive/MyDrive/IRDM/JSON Files/converter.py'
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6mTL4U1uLZqNG7WBIVIItM.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6oKP2GAD2wcMjQi3FcPqb0.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6oiEQUnSDwZuPH1em8R6nv.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6ptLKFizTiJpOgBmfqEFLw.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6q5o8uZbGkgrhAAXWwYQKR.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6vw8LpT5mEnSTQsNbeBQQg.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6w4clejHZPavi5JfObLxr8.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6x9cf4lt6M5lPLyexz9gqn.json
# /content/drive/MyDrive/IRDM/JSON Files/6/M/show_6Mk7Wk6cmrgXWnitO3NdYe/6yDGmQRnO3ywz8C6MfQzlF.json
# ...
